-- %% [markdown]
-- # [K22CNT3_lession10]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [K22CNT3_lession10]    Script Date: 7/3/2024 9:17:58 AM ******/
CREATE DATABASE [K22CNT3_lession10]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'K22CNT3_lession10', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER03\MSSQL\DATA\K22CNT3_lession10.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'K22CNT3_lession10_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER03\MSSQL\DATA\K22CNT3_lession10_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [K22CNT3_lession10] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [K22CNT3_lession10].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [K22CNT3_lession10] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET ARITHABORT OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [K22CNT3_lession10] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [K22CNT3_lession10] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET  ENABLE_BROKER 
GO
ALTER DATABASE [K22CNT3_lession10] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [K22CNT3_lession10] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET RECOVERY FULL 
GO
ALTER DATABASE [K22CNT3_lession10] SET  MULTI_USER 
GO
ALTER DATABASE [K22CNT3_lession10] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [K22CNT3_lession10] SET DB_CHAINING OFF 
GO
ALTER DATABASE [K22CNT3_lession10] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [K22CNT3_lession10] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [K22CNT3_lession10] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [K22CNT3_lession10] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'K22CNT3_lession10', N'ON'
GO
ALTER DATABASE [K22CNT3_lession10] SET QUERY_STORE = ON
GO
ALTER DATABASE [K22CNT3_lession10] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[NvdAccount]

-- %%
USE [K22CNT3_lession10]
GO

-- %%
/****** Object:  Table [dbo].[NvdAccount]    Script Date: 7/3/2024 9:17:59 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NvdAccount](
	[NvdID] [int] IDENTITY(1,1) NOT NULL,
	[NvdUserName] [nvarchar](50) NULL,
	[NvdPassWord] [nvarchar](50) NULL,
	[NvdFullName] [nvarchar](50) NULL,
	[NvdEmail] [nvarchar](50) NULL,
	[NvdPhone] [nvarchar](50) NULL,
	[NvdActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[NvdID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [K22CNT3_lession10]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [K22CNT3_lession10] SET  READ_WRITE 
GO
